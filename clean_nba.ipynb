# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_clean = pd.read_csv("df_clean.csv")
df_clean
# Out:
#               Name  Number            Team Position  Age Height  Weight  \
# 0    Avery Bradley       0  Boston Celtics       PG   25    6-2     180
# 1      Jae Crowder      99  Boston Celtics       SF   25    6-6     235
# 2      R.J. Hunter      28  Boston Celtics       SG   22    6-5     185
# 3    Jonas Jerebko       8  Boston Celtics       PF   29   6-10     231
# 4     Amir Johnson      90  Boston Celtics       PF   29    6-9     240
# ..             ...     ...             ...      ...  ...    ...     ...
# 441     Trey Lyles      41       Utah Jazz       PF   20   6-10     234
# 442   Shelvin Mack       8       Utah Jazz       PG   26    6-3     203
# 443      Raul Neto      25       Utah Jazz       PG   24    6-1     179
# 444   Tibor Pleiss      21       Utah Jazz        C   26    7-3     256
# 445    Jeff Withey      24       Utah Jazz        C   26    7-0     231
#
#        Salary Salary_format
# 0     7730337     7.730.337
# 1     6796117     6.796.117
# 2     1148640     1.148.640
# 3     5000000     5.000.000
# 4    12000000    12.000.000
# ..        ...           ...
# 441   2239800     2.239.800
# 442   2433333     2.433.333
# 443    900000       900.000
# 444   2900000     2.900.000
# 445    947276       947.276
#
# [446 rows x 9 columns]

# %% [markdown]
# ##### Cuantos numeros tiene cada posicion ?

# %%
df_clean['Number'].unique()
# Out:
# array([ 0, 99, 28,  8, 90, 55, 41, 12, 36,  7,  4, 11, 13, 44, 22, 21, 24,
#         2, 10,  6,  1, 33, 14, 15, 30, 17, 43,  3,  9, 42, 18, 23,  5, 39,
#        31, 35, 20, 92, 54, 19, 40, 34, 45, 32, 25, 50, 37, 26, 16, 52, 27,
#        77, 88], dtype=int64)

# %%
df_clean['Position'].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
df_clean.groupby('Position')["Number"].size().reset_index().sort_values("Position",ascending= False)
# Out:
#   Position  Number
# 4       SG      99
# 3       SF      84
# 2       PG      88
# 1       PF      97
# 0        C      78

# %% [markdown]
# ##### How many players are there in each position?
# * Position with more players

# %%
df_1 = df_clean.copy()
df_1.head()
# Out:
#             Name  Number            Team Position  Age Height  Weight  \
# 0  Avery Bradley       0  Boston Celtics       PG   25    6-2     180
# 1    Jae Crowder      99  Boston Celtics       SF   25    6-6     235
# 2    R.J. Hunter      28  Boston Celtics       SG   22    6-5     185
# 3  Jonas Jerebko       8  Boston Celtics       PF   29   6-10     231
# 4   Amir Johnson      90  Boston Celtics       PF   29    6-9     240
#
#      Salary Salary_format
# 0   7730337     7.730.337
# 1   6796117     6.796.117
# 2   1148640     1.148.640
# 3   5000000     5.000.000
# 4  12000000    12.000.000

# %%
df_top = df_1['Number'].value_counts().reset_index()
df_top[df_top['count'] >= 20]
# Out:
#    Number  count
# 0       5     22
# 1       3     21
# 2       0     20
# 3       1     20

# %% [markdown]
# ##### Equipo con salario mas alto

# %%
df_2 = df_1.copy()
df_2.head()
# Out:
#             Name  Number            Team Position  Age Height  Weight  \
# 0  Avery Bradley       0  Boston Celtics       PG   25    6-2     180
# 1    Jae Crowder      99  Boston Celtics       SF   25    6-6     235
# 2    R.J. Hunter      28  Boston Celtics       SG   22    6-5     185
# 3  Jonas Jerebko       8  Boston Celtics       PF   29   6-10     231
# 4   Amir Johnson      90  Boston Celtics       PF   29    6-9     240
#
#      Salary Salary_format
# 0   7730337     7.730.337
# 1   6796117     6.796.117
# 2   1148640     1.148.640
# 3   5000000     5.000.000
# 4  12000000    12.000.000

# %%
df_2['Team'].nunique()
# Out:
# 30

# %%
df_salary_top = df_2.groupby('Team')['Salary'].sum().reset_index().sort_values('Salary',ascending= False)
df_cleveland = df_salary_top[df_salary_top['Team'] == 'Cleveland Cavaliers']
df_cleveland
# Out:
#                   Team     Salary
# 5  Cleveland Cavaliers  106988689

# %%
df_cleve = df_2[df_2['Team'] == 'Cleveland Cavaliers']
df_cleve
# Out:
#                     Name  Number                 Team Position  Age Height  \
# 164  Matthew Dellavedova       8  Cleveland Cavaliers       PG   25    6-4
# 165        Channing Frye       9  Cleveland Cavaliers       PF   33   6-11
# 166         Kyrie Irving       2  Cleveland Cavaliers       PG   24    6-3
# 167         LeBron James      23  Cleveland Cavaliers       SF   31    6-8
# 168    Richard Jefferson      24  Cleveland Cavaliers       SF   35    6-7
# 169          James Jones       1  Cleveland Cavaliers       SG   35    6-8
# 170           Sasha Kaun      14  Cleveland Cavaliers        C   31   6-11
# 171           Kevin Love       0  Cleveland Cavaliers       PF   27   6-10
# 172         Jordan McRae      12  Cleveland Cavaliers       SG   25    6-5
# 173       Timofey Mozgov      20  Cleveland Cavaliers        C   29    7-1
# 174        Iman Shumpert       4  Cleveland Cavaliers       SG   25    6-5
# 175           J.R. Smith       5  Cleveland Cavaliers       SG   30    6-6
# 176     Tristan Thompson      13  Cleveland Cavaliers        C   25    6-9
# 177          Mo Williams      52  Cleveland Cavaliers       PG   33    6-1
#
#      Weight    Salary Salary_format
# 164     198   1147276     1.147.276
# 165     255   8193029     8.193.029
# 166     193  16407501    16.407.501
# 167     250  22970500    22.970.500
# 168     233    947276       947.276
# 169     218    947276       947.276
# 170     260   1276000     1.276.000
# 171     251  19689000    19.689.000
# 172     179    111196       111.196
# 173     275   4950000     4.950.000
# 174     220   8988765     8.988.765
# 175     225   5000000     5.000.000
# 176     238  14260870    14.260.870
# 177     198   2100000     2.100.000

# %%
df_cleve['Salary'].sum()
# Out:
# 106988689

# %% [markdown]
# ##### Jugadores con el salario mas alto

# %%
df_3 = df_2.copy()
df_3
# Out:
#               Name  Number            Team Position  Age Height  Weight  \
# 0    Avery Bradley       0  Boston Celtics       PG   25    6-2     180
# 1      Jae Crowder      99  Boston Celtics       SF   25    6-6     235
# 2      R.J. Hunter      28  Boston Celtics       SG   22    6-5     185
# 3    Jonas Jerebko       8  Boston Celtics       PF   29   6-10     231
# 4     Amir Johnson      90  Boston Celtics       PF   29    6-9     240
# ..             ...     ...             ...      ...  ...    ...     ...
# 441     Trey Lyles      41       Utah Jazz       PF   20   6-10     234
# 442   Shelvin Mack       8       Utah Jazz       PG   26    6-3     203
# 443      Raul Neto      25       Utah Jazz       PG   24    6-1     179
# 444   Tibor Pleiss      21       Utah Jazz        C   26    7-3     256
# 445    Jeff Withey      24       Utah Jazz        C   26    7-0     231
#
#        Salary Salary_format
# 0     7730337     7.730.337
# 1     6796117     6.796.117
# 2     1148640     1.148.640
# 3     5000000     5.000.000
# 4    12000000    12.000.000
# ..        ...           ...
# 441   2239800     2.239.800
# 442   2433333     2.433.333
# 443    900000       900.000
# 444   2900000     2.900.000
# 445    947276       947.276
#
# [446 rows x 9 columns]

# %%
df_3_top_salary_player = df_3[['Name','Team', 'Salary']].sort_values('Salary', ascending= False)
df_3_top_salary_player.iloc[:3]
# Out:
#                 Name                 Team    Salary
# 107      Kobe Bryant   Los Angeles Lakers  25000000
# 167     LeBron James  Cleveland Cavaliers  22970500
# 32   Carmelo Anthony      New York Knicks  22875000

# %% [markdown]
# ##### Posiciones con salarios mas altos

# %%
df_4 = df_3.copy()
df_4.head()
# Out:
#             Name  Number            Team Position  Age Height  Weight  \
# 0  Avery Bradley       0  Boston Celtics       PG   25    6-2     180
# 1    Jae Crowder      99  Boston Celtics       SF   25    6-6     235
# 2    R.J. Hunter      28  Boston Celtics       SG   22    6-5     185
# 3  Jonas Jerebko       8  Boston Celtics       PF   29   6-10     231
# 4   Amir Johnson      90  Boston Celtics       PF   29    6-9     240
#
#      Salary Salary_format
# 0   7730337     7.730.337
# 1   6796117     6.796.117
# 2   1148640     1.148.640
# 3   5000000     5.000.000
# 4  12000000    12.000.000

# %%
df_4.groupby('Position')['Salary'].sum().reset_index()
# Out:
#   Position     Salary
# 0        C  465430056
# 1       PF  442560850
# 2       PG  446848971
# 3       SF  408020976
# 4       SG  396976258

# %% [markdown]
# ##### Average weight

# %%
df_5 = df_4.copy()
df_5
# Out:
#               Name  Number            Team Position  Age Height  Weight  \
# 0    Avery Bradley       0  Boston Celtics       PG   25    6-2     180
# 1      Jae Crowder      99  Boston Celtics       SF   25    6-6     235
# 2      R.J. Hunter      28  Boston Celtics       SG   22    6-5     185
# 3    Jonas Jerebko       8  Boston Celtics       PF   29   6-10     231
# 4     Amir Johnson      90  Boston Celtics       PF   29    6-9     240
# ..             ...     ...             ...      ...  ...    ...     ...
# 441     Trey Lyles      41       Utah Jazz       PF   20   6-10     234
# 442   Shelvin Mack       8       Utah Jazz       PG   26    6-3     203
# 443      Raul Neto      25       Utah Jazz       PG   24    6-1     179
# 444   Tibor Pleiss      21       Utah Jazz        C   26    7-3     256
# 445    Jeff Withey      24       Utah Jazz        C   26    7-0     231
#
#        Salary Salary_format
# 0     7730337     7.730.337
# 1     6796117     6.796.117
# 2     1148640     1.148.640
# 3     5000000     5.000.000
# 4    12000000    12.000.000
# ..        ...           ...
# 441   2239800     2.239.800
# 442   2433333     2.433.333
# 443    900000       900.000
# 444   2900000     2.900.000
# 445    947276       947.276
#
# [446 rows x 9 columns]

# %%
#Average weight in all df
df_5['Weight'].mean()
# Out:
# 221.75336322869956

# %%
df_5.groupby('Team')['Weight'].describe()
# Out:
#                         count        mean        std    min     25%    50%  \
# Team
# Atlanta Hawks            15.0  221.266667  25.982045  172.0  203.00  225.0
# Boston Celtics           14.0  220.500000  26.246612  180.0  196.25  225.5
# Brooklyn Nets            15.0  215.600000  24.377390  175.0  200.00  216.0
